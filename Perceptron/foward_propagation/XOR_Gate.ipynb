# %%
import numpy as np

# %%
x=np.array([
    [0,0],
    [0,1],
    [1,0],
    [1,1]
])
y=np.array([0,1,1,0])

x,y
# Out:
# (array([[0, 0],
#         [0, 1],
#         [1, 0],
#         [1, 1]]),
#  array([0, 1, 1, 0]))

# %%
w=np.zeros(2)
b=0
learning_rate=0.1
epochs=10

print("Initial Weights:",w)
print("Initial Bias:",b)
# Out:
# Initial Weights: [0. 0.]
# Initial Bias: 0

# %%
def step_function(z):
    return 1 if z>=0 else 0

# %%
for epoch in range(epochs):
    print(f"Epoch {epoch+1}/{epochs}")
    for i in range(len(x)):
        linear_output=np.dot(w,x[i])+b
        y_pred=step_function(linear_output)

        update=learning_rate*(y[i]-y_pred)
        w+=update*x[i]
        b+=update
        print(f"Sample {i+1}, Weights: {w}, Bias: {b}")
# Out:
# Epoch 1/10
# Sample 1, Weights: [0. 0.], Bias: -0.1
# Sample 2, Weights: [0.  0.1], Bias: 0.0
# Sample 3, Weights: [0.  0.1], Bias: 0.0
# Sample 4, Weights: [-0.1  0. ], Bias: -0.1
# Epoch 2/10
# Sample 1, Weights: [-0.1  0. ], Bias: -0.1
# Sample 2, Weights: [-0.1  0.1], Bias: 0.0
# Sample 3, Weights: [0.  0.1], Bias: 0.1
# Sample 4, Weights: [-0.1  0. ], Bias: 0.0
# Epoch 3/10
# Sample 1, Weights: [-0.1  0. ], Bias: -0.1
# Sample 2, Weights: [-0.1  0.1], Bias: 0.0
# Sample 3, Weights: [0.  0.1], Bias: 0.1
# Sample 4, Weights: [-0.1  0. ], Bias: 0.0
# Epoch 4/10
# Sample 1, Weights: [-0.1  0. ], Bias: -0.1
# Sample 2, Weights: [-0.1  0.1], Bias: 0.0
# Sample 3, Weights: [0.  0.1], Bias: 0.1
# Sample 4, Weights: [-0.1  0. ], Bias: 0.0
# Epoch 5/10
# Sample 1, Weights: [-0.1  0. ], Bias: -0.1
# Sample 2, Weights: [-0.1  0.1], Bias: 0.0
# Sample 3, Weights: [0.  0.1], Bias: 0.1
# Sample 4, Weights: [-0.1  0. ], Bias: 0.0
# Epoch 6/10
# Sample 1, Weights: [-0.1  0. ], Bias: -0.1
# ...

# %%
print("Final Weight:",w)
print("Final Bias:",b)
# Out:
# Final Weight: [-0.1  0. ]
# Final Bias: 0.0

# %%
test_values=[[0,0],[0,1],[1,0],[1,1]]
for i in range(len(test_values)):
    z=np.dot(w,test_values[i])+b
    y_pred=step_function(z)
    print(f"Input: {test_values[i]}, Predicted Output: {y_pred}, Actual Output: {y[i]}")
# Out:
# Input: [0, 0], Predicted Output: 1, Actual Output: 0
# Input: [0, 1], Predicted Output: 1, Actual Output: 1
# Input: [1, 0], Predicted Output: 0, Actual Output: 1
# Input: [1, 1], Predicted Output: 0, Actual Output: 0

# %%
#plotting decision boundary
import matplotlib.pyplot as plt
x1=np.array([0,1])
x2=-(w[0]*x1+b)/w[1]
plt.plot(x1,x2,label="Decision Boundary")
plt.scatter(x[:,0],x[:,1],c=y,label="Data Points")
plt.xlabel("Input 1")
plt.ylabel("Input 2")
plt.title("OR Gate Decision Boundary")
plt.legend()
plt.grid()
plt.show()
# Out:
# C:\Users\SAKSHITHA\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in true_divide
#   after removing the cwd from sys.path.
# C:\Users\SAKSHITHA\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in true_divide
#   after removing the cwd from sys.path.
